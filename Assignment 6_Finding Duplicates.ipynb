# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 78.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 70.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 113.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65457 entries, 0 to 65456
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
num_duplicates = df.duplicated().sum()
print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 20

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
dup_df = df[df.duplicated(keep=False)]

print("Total rows involved in duplicates:", dup_df.shape[0])
# Out:
# Total rows involved in duplicates: 40

# %%
dup_df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
# Columns used to identify duplicates
subset_cols = ['MainBranch', 'Employment', 'RemoteWork']

# Identify duplicate rows based on the selected columns
dup_df = df[df.duplicated(subset=subset_cols, keep=False)]

print("Number of rows in duplicate groups:", dup_df.shape[0])
# Out:
# Number of rows in duplicate groups: 65290

# %%
# Group duplicate rows by the selected subset columns
groups = dup_df.groupby(subset_cols)

# Dictionary to store results
identical_columns = {}

# Analyze each column for identical values within duplicate groups
for col in df.columns:
    if col not in subset_cols:
        identical_columns[col] = (groups[col].nunique() == 1).sum()

# Convert results to a sorted DataFrame
identical_columns_df = (
    pd.DataFrame.from_dict(
        identical_columns,
        orient='index',
        columns=['Groups_with_identical_values']
    )
    .sort_values(by='Groups_with_identical_values', ascending=False)
)

identical_columns_df
# Out:
#                        Groups_with_identical_values
# Check                                           319
# ICorPM                                           97
# AIThreat                                         88
# SOAccount                                        85
# AINextLess integrated                            76
# ...                                             ...
# YearsCodePro                                      8
# TechEndorse                                       8
# BuyNewTool                                        7
# CodingActivities                                  1
# ResponseId                                        0
#
# [111 rows x 1 columns]

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
subset_cols = ['MainBranch', 'Employment', 'RemoteWork']

dup_df = df[df.duplicated(subset=subset_cols, keep=False)]

# %%
import matplotlib.pyplot as plt
country_counts = dup_df['Country'].value_counts()

plt.figure()

top10_countries = dup_df['Country'].value_counts().head(10)

plt.figure()
top10_countries.plot(kind='bar')
plt.title('Top 10 Countries with Duplicate Rows')
plt.xlabel('Country')
plt.ylabel('Number of Duplicate Rows')
plt.show()

plt.title('Distribution of Duplicate Rows by Country')
plt.xlabel('Country')
plt.ylabel('Number of Duplicate Rows')
plt.show()

# %%
import matplotlib.pyplot as plt

top10_countries = dup_df['Country'].value_counts().head(10)

plt.figure()
top10_countries.plot(kind='bar')
plt.title('Top 10 Countries with Duplicate Rows')
plt.xlabel('Country')
plt.ylabel('Number of Duplicate Rows')
plt.show()

# %%
employment_counts = dup_df['Employment'].value_counts()

plt.figure()
employment_counts.plot(kind='bar')
plt.title('Distribution of Duplicate Rows by Employment')
plt.xlabel('Employment')
plt.ylabel('Number of Duplicate Rows')
plt.show()

# %%
top10_employment = dup_df['Employment'].value_counts().head(10)

plt.figure()
top10_employment.plot(kind='bar')
plt.title('Top 10 Employment Categories with Duplicate Rows')
plt.xlabel('Employment')
plt.ylabel('Number of Duplicate Rows')
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
unique_cols = ['ResponseId']  # Each response should have a unique ID
# Alternatively, if ResponseId is not unique, use a combination of:
# ['MainBranch', 'Employment', 'RemoteWork', 'Country', 'Age']

# %%
# Remove duplicates while keeping the first occurrence
df_cleaned = df.drop_duplicates(subset=unique_cols, keep='first')

print("Original dataset size:", df.shape[0])
print("Dataset size after removing duplicates:", df_cleaned.shape[0])
# Out:
# Original dataset size: 65457
# Dataset size after removing duplicates: 65437

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# Task 5: Documentation – Identifying and Removing Duplicates
# 1. Objective
#
# The goal of this task is to systematically identify and remove duplicate entries in the dataset while preserving meaningful data. Duplicates can bias analysis, so it is important to detect them carefully and remove them based on logical criteria.
#
# 2. Process Overview
#
# The process was divided into the following steps:
#
# Step 1: Initial Duplicate Detection
#
# Method: Use df.duplicated() to identify rows that are exact duplicates across all columns.
#
# Outcome: Counted the number of completely identical rows.
#
# Insight: Full-row duplicates are strict; minor differences in optional or numeric columns can cause meaningful duplicates to be missed.
#
#
#
# Step 2: Duplicate Detection Based on Selected Columns
#
# Rationale: Some columns are more meaningful for defining duplicates than the entire row.
#
# Outcome: Captured duplicate patterns where respondents share similar professional and work characteristics.
#
#
#
# Step 3: Analyze Characteristics of Duplicate Rows
#
# Method: Group duplicates by the subset columns and check which other columns have identical values across these groups.
#
# Purpose: Understand which attributes are consistent across duplicate entries (shared characteristics) and which vary.
#
# Outcome: Produced a table showing the number of duplicate groups in which each column remains identical.
#
#
#
# Step 4: Visualize Duplicate Distribution
#
# Method: Use bar charts to show how duplicates are distributed across important categorical fields, such as Country and Employment.
#
# Enhancement: Limited visualization to top 10 categories for readability.
#
# Purpose: Identify concentrations of duplicates in certain demographics or employment types.
#
#
#
# Step 5: Strategic Removal of Duplicates
#
# Method: Determine which columns are critical for defining uniqueness.
#
# Option 1: ResponseId (each survey response is unique)
#
# Option 2: A subset of meaningful columns (MainBranch, Employment, RemoteWork, Country, Age)
#
# Implementation: Use drop_duplicates(subset=..., keep='first') to remove duplicates while preserving the first occurrence.
#
# Outcome: Cleaned dataset ready for further analysis.
#
#
#
# 6. Key Insights
#
# Full-row duplication is too strict for survey data because minor variations exist in optional fields.
#
# Selecting a subset of critical columns allows for a more meaningful duplicate removal strategy.
#
# Analyzing duplicate characteristics helps identify which attributes are consistent and which vary among duplicate patterns.
#
# Visualizations highlight where duplicates are concentrated, aiding in data cleaning and reporting.
#
#
# 7. Conclusion
#
# The duplicate identification and removal process ensures that the dataset is clean, consistent, and ready for analysis.
#
# Strategic removal using subset columns balances data integrity and prevents loss of meaningful information.
#
# Proper documentation of this process provides transparency and reproducibility for any downstream analytics or reporting.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# Specific columns like ResponseId, MainBranch, Employment, and RemoteWork were chosen for duplicate detection because they define the core identity of each survey entry. Subset-based detection avoids the pitfalls of full-row duplication and ensures meaningful data is preserved while eliminating redundant entries.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
